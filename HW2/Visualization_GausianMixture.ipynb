# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats
from sklearn.mixture import GaussianMixture

# %%
# generated data points
data1 = np.array([1.495786, 3.595622, -4.020066, 0.856639, 0.202497, -4.207561, -3.204644, 
                 0.939387, 1.580042, 10.815956, -1.490510, 5.183897, 5.439559, 1.588706, 
                 -4.652567, -1.108811, 1.015783, -0.294432, -0.336392, -3.354970, 6.326117, 
                 -0.257900, 0.196872, -4.231968, 6.576832, -3.162919, 8.292762, 4.722734, 
                 -2.605112, -1.903913, -3.166682, 5.568035, 1.123590, 4.389122, 2.029446, 
                 -0.804800, -4.827492, 0.977946, 0.371167, -1.965324])

# plot data points
plt.figure(figsize=(10, 6))
plt.plot(data1, np.zeros_like(data1), "ko", label='Data points')

# plot estimated probability density function
mean = np.mean(data1)
sigma = np.std(data1)
x = np.linspace(-10, 15, 1000)
pdf = scipy.stats.norm.pdf(x, mu, sigma)
plt.plot(x, pdf, "turquoise", label=f"estimated one-component pdf\n(mu={mean:.2f}, sigma={sigma:.2f})")

# plot prior distribution
mu, sigma = 0.54, 3.54
x = np.linspace(-10, 15, 1000)
prior_pdf = scipy.stats.norm.pdf(x, mu, sigma)
plt.plot(x, prior_pdf, 'b-', label="prior one-component pdf\n(mu=0.54, sigma=3.54)")

# plot mixture model using Expectation-Maximization
gmm = GaussianMixture(n_components=2).fit(data1.reshape(-1, 1))
gmm_mean = gmm.means_.flatten()
gmm_std = np.sqrt(gmm.covariances_.flatten())
weights = gmm.weights_.flatten()

# pdf of mixture model
gmm_pdf = weights[0] * scipy.stats.norm.pdf(x, gmm_mean[0], gmm_std[0]) + weights[1] * scipy.stats.norm.pdf(x, gmm_mean[1], gmm_std[1])
plt.plot(x, gmm_pdf,"r-", label=f"two-component mixture model pdf\n(w={weights[0]:.2f}, (mu1={gmm_mean[0]:.2f}, sigma1={gmm_std[0]:.2f})\n(mu2={gmm_mean[1]:.2f}, sigma2={gmm_std[1]:.2f}))")

plt.suptitle("Visualization of generated datasets from one-component model")
plt.title("(mu,sigma) =  (0.54,3.54)")
plt.xlabel("data points")
plt.ylabel("Probability Density")
plt.legend(loc="upper right")
plt.grid()
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data1 = np.array([7.163725, 1.569430, 8.714586, 9.479235, 0.994448, 4.387438, 
                 6.087732, -0.508273, 4.651071, 7.425709, 5.413454, 7.360649, 
                 0.805307, 4.902059, 1.951146, 2.041172, -1.798595, 8.277273, 
                 8.936025, 4.913107, 0.485754, 7.198761, 1.831882, 7.221062, 
                 10.655813, 4.540989, -0.953403, 2.648075, 3.061849, 7.233263, 
                 5.625165, -2.419259, 5.295121, 2.581270, 4.172056, 10.484312, 
                 0.368813, 7.036827, -2.140647, 7.336892])
# plot data points
plt.figure(figsize=(10, 6))
plt.plot(data1, np.zeros_like(data1), "ko", label='Data points')

# plot estimated probability density function
mean = np.mean(data1)
sigma = np.std(data1)
x = np.linspace(-10, 15, 1000)
pdf = scipy.stats.norm.pdf(x, mu, sigma)
plt.plot(x, pdf, "turquoise", label=f"estimated one-component pdf\n(mu={mean:.2f}, sigma={sigma:.2f})")

# plot prior distribution
mu, sigma = 4.19, 3.16
x = np.linspace(-10, 15, 1000)
prior_pdf = scipy.stats.norm.pdf(x, mu, sigma)
plt.plot(x, prior_pdf, 'b-', label="prior one-component pdf\n(mu=0.54, sigma=3.54)")

# plot mixture model using Expectation-Maximization
gmm = GaussianMixture(n_components=2).fit(data1.reshape(-1, 1))
gmm_mean = gmm.means_.flatten()
gmm_std = np.sqrt(gmm.covariances_.flatten())
weights = gmm.weights_.flatten()

# pdf of mixture model
gmm_pdf = weights[0] * scipy.stats.norm.pdf(x, gmm_mean[0], gmm_std[0]) + weights[1] * scipy.stats.norm.pdf(x, gmm_mean[1], gmm_std[1])
plt.plot(x, gmm_pdf,"r-", label=f"two-component mixture model pdf\n(m={weights[0]:.2f}, (mu1={gmm_mean[0]:.2f}, sigma1={gmm_std[0]:.2f})\n(mu2={gmm_mean[1]:.2f}, sigma2={gmm_std[1]:.2f}))")

plt.suptitle("Visualization of generated datasets from one-component model")
plt.title("(mu,sigma) =  (4.19,3.16)")
plt.xlabel("data points")
plt.ylabel("Probability Density")
plt.legend(loc="upper left")
plt.grid()
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# generating data with:  m; (mu1,sigma1); (mu2,sigma2) =  0.477; (8.83,1.30); (-1.44,2.71)
data1 = np.array([-0.327591, 10.866707, 5.421097, 10.530837, 10.779664, 7.164254,
                 -2.918849, 0.384546, -0.751307, 1.209718, -1.746937, 9.958999,
                 -1.862228, 0.682737, 10.701707, 0.108380, -1.082408, 9.513963,
                 10.575257, 11.620190, -4.537381, 7.460265, 8.982517, 8.409146,
                 6.135797, 4.458461, 1.213730, -1.046143, 5.535058, -6.872466,
                 9.348899, 7.414353, 9.967657, -1.222320, 8.883465, 6.972535,
                 8.488631, 10.597354, -1.063614, -10.645773])
# plot data point
plt.figure(figsize=(10, 6))
plt.plot(data1, np.zeros_like(data1), "ko", label='Data points')

# prior mixture model pdf
m, mu1, sigma1, mu2, sigma2 = 0.477, 8.83, 1.30, -1.44, 2.71
x = np.linspace(-10, 15, 1000)
pdf = m * scipy.stats.norm.pdf(x, mu1, sigma1) + (1-m) * scipy.stats.norm.pdf(x, mu2, sigma2)
plt.plot(x, pdf, "b-", label=f"prior two-component mixture model\n(m={m}, (mu1={mu1}, sigma1={sigma2}),\n(mu2={mu2}, sigma2={sigma2}))")

# plot estimated probability density function
mean = np.mean(data1)
sigma = np.std(data1)
x = np.linspace(-10, 15, 1000)
pdf = scipy.stats.norm.pdf(x, mu, sigma)
plt.plot(x, pdf, "turquoise", label=f"estimated one-component pdf\n(mu={mean:.2f}, sigma={sigma:.2f})")

# plot estimated mixture model using Expectation-Maximization
gmm = GaussianMixture(n_components=2).fit(data1.reshape(-1, 1))
gmm_mean = gmm.means_.flatten()
gmm_std = np.sqrt(gmm.covariances_.flatten())
weights = gmm.weights_.flatten()

# pdf of mixture model
gmm_pdf = weights[0] * scipy.stats.norm.pdf(x, gmm_mean[0], gmm_std[0]) + weights[1] * scipy.stats.norm.pdf(x, gmm_mean[1], gmm_std[1])
plt.plot(x, gmm_pdf,"r-", label=f"two-component mixture model pdf\n(m={weights[0]:.2f}, (mu1={gmm_mean[0]:.2f}, sigma1={gmm_std[0]:.2f})\n(mu2={gmm_mean[1]:.2f}, sigma2={gmm_std[1]:.2f}))")


plt.suptitle("Visualization of generated datasets from mixture model")
plt.title("m; (mu1,sigma1); (mu2,sigma2) =  0.477; (8.83,1.30); (-1.44,2.71)")
plt.xlabel("data points")
plt.ylabel("Probability Density")
plt.legend(loc="upper left")
plt.grid()
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# generating data with:  m; (mu1,sigma1); (mu2,sigma2) =  0.106; (7.99,1.39); (-3.64,1.45)
data1 = np.array([-1.563819, -0.047939, 8.764149, -3.108655, -3.712579, -2.858499,
                 -2.555350, -3.298115, -3.315344, -2.342890, -2.193381, -3.862934,
                 -2.171244, -5.707829, -4.712343, -2.944319, -2.743267, -1.839987,
                 -4.967393, -4.595637, -4.818788, -5.900362, -0.669764, -5.013821,
                 -2.838083, -5.111778, -4.081952, -5.930175, 9.512866, -5.112993,
                 -4.092738, -4.053584, -4.614575, -0.748183, -2.251403, -6.139164,
                 -3.983392, -4.482734, -3.655723, -4.185228])
# plot data point
plt.figure(figsize=(10, 6))
plt.plot(data1, np.zeros_like(data1), "ko", label='Data points')

# prior mixture model pdf
m, mu1, sigma1, mu2, sigma2 = 0.106, 7.99, 1.39, -3.64, 1.45
x = np.linspace(-10, 15, 1000)
pdf = m * scipy.stats.norm.pdf(x, mu1, sigma1) + (1-m) * scipy.stats.norm.pdf(x, mu2, sigma2)
plt.plot(x, pdf, "b-", label=f"prior two-component mixture model\n(m={m}, (mu1={mu1}, sigma1={sigma2}),\n(mu2={mu2}, sigma2={sigma2}))")

# plot estimated probability density function
mean = np.mean(data1)
sigma = np.std(data1)
x = np.linspace(-10, 15, 1000)
pdf = scipy.stats.norm.pdf(x, mu, sigma)
plt.plot(x, pdf, "turquoise", label=f"estimated one-component pdf\n(mu={mean:.2f}, sigma={sigma:.2f})")

# plot estimated mixture model using Expectation-Maximization
gmm = GaussianMixture(n_components=2).fit(data1.reshape(-1, 1))
gmm_mean = gmm.means_.flatten()
gmm_std = np.sqrt(gmm.covariances_.flatten())
weights = gmm.weights_.flatten()

# pdf of mixture model
gmm_pdf = weights[0] * scipy.stats.norm.pdf(x, gmm_mean[0], gmm_std[0]) + weights[1] * scipy.stats.norm.pdf(x, gmm_mean[1], gmm_std[1])
plt.plot(x, gmm_pdf,"r-", label=f"two-component mixture model pdf\n(m={weights[0]:.2f}, (mu1={gmm_mean[0]:.2f}, sigma1={gmm_std[0]:.2f})\n(mu2={gmm_mean[1]:.2f}, sigma2={gmm_std[1]:.2f}))")


plt.suptitle("Visualization of generated datasets from mixture model")
plt.title("m; (mu1,sigma1); (mu2,sigma2) =  0.106; (7.99,1.39); (-3.64,1.45)")
plt.xlabel("data points")
plt.ylabel("Probability Density")
plt.legend(loc="upper right")
plt.grid()
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
